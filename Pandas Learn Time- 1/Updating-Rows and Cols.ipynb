# %%
import pandas as pd

# %%
person = {
 "first" : "corey",
 "last" : "schafer",
"email" :"coreyschafer@email.com"
}


people = {
 "first" : ["corey"],
 "last" : ["schafer"],
"email" : ["coreyschafer@email.com"]
}

people = {
 "first" : ['corey', 'Jane', 'John'],
 "last" : ['schafer', 'Doe', 'Doe'],
"email" : ['coreyschafer@email.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df['last']
# Out:
# 0    schafer
# 1        Doe
# 2        Doe
# Name: last, dtype: object

# %%
df[['last', 'first']]
# Out:
#       last  first
# 0  schafer  corey
# 1      Doe   Jane
# 2      Doe   John

# %%
df[['last', 'first','email']]
# Out:
#       last  first                   email
# 0  schafer  corey  coreyschafer@email.com
# 1      Doe   Jane       JaneDoe@email.com
# 2      Doe   John       JohnDoe@email.com

# %%
df['last']            # ✓ single column — returns a Series
df[['last']]          # ✓ single column — returns a DataFrame
df[['last', 'first']] # ✓ multiple columns — returns a DataFrame

# df['last', 'first']   # ✗ KeyError — pandas sees this as a tuple key
# Out:
#       last  first
# 0  schafer  corey
# 1      Doe   Jane
# 2      Doe   John

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns = ['first_name', 'last_name','email']

# %%
df
# Out:
#   first_name last_name                   email
# 0      corey   schafer  coreyschafer@email.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.rename(columns={'first_name': 'first'})
# Out:
#    first last_name                   email
# 0  corey   schafer  coreyschafer@email.com
# 1   Jane       Doe       JaneDoe@email.com
# 2   John       Doe       JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME                   EMAIL
# 0      corey   schafer  coreyschafer@email.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df[['FIRST_NAME']]
# Out:
#   FIRST_NAME
# 0      corey
# 1       Jane
# 2       John

# %%
df.columns = df.columns.str.replace('_','-')
df
# Out:
#   FIRST-NAME LAST-NAME                   EMAIL
# 0      corey   schafer  coreyschafer@email.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.columns = df.columns.str.replace('-','_')
df
# Out:
#   FIRST_NAME LAST_NAME                   EMAIL
# 0      corey   schafer  coreyschafer@email.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df
# Out:
#   first_name last_name                   email
# 0      corey   schafer  coreyschafer@email.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.rename(columns={'first_name':'first', 'last_name':'last'},inplace = True)

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df.loc[2] = ['John','Smith', 'JohnSmith@email.com']

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John    Smith     JohnSmith@email.com

# %%
df.loc[2, ['last','email']] = ['Doe', 'JohnDoe@email.com']

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df.loc[2, 'last'] = 'Smith'

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John    Smith       JohnDoe@email.com

# %%
df.at[2, 'last'] = 'Doe'

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
filt = (df['email'] == 'JohnDoe@email.com')

# %%
df.loc[filt,['email','last']]
# Out:
#                email last
# 2  JohnDoe@email.com  Doe

# %%
df.loc[filt]
# Out:
#   first last              email
# 2  John  Doe  JohnDoe@email.com

# %%
df.loc[filt, 'email'].str.lower()
# Out:
# 2    johndoe@email.com
# Name: email, dtype: object

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df['email'] = df['email'].str.lower()

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       janedoe@email.com
# 2   John      Doe       johndoe@email.com

# %%
# apply, applymap, map, replace

# %%
#so the apply helps use to use a method on the series or on dataframe
df['email'].apply(len)
# Out:
# 0    22
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()
def lower_email(email):
    return email.lower()

df['email'] = df['email'].apply(update_email)

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  COREYSCHAFER@EMAIL.COM
# 1   Jane      Doe       JANEDOE@EMAIL.COM
# 2   John      Doe       JOHNDOE@EMAIL.COM

# %%
df['email'] = df['email'].apply(lower_email)
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       janedoe@email.com
# 2   John      Doe       johndoe@email.com

# %%
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df.applymap(len)
# Out:
# C:\Users\vegeshsai_boppana\AppData\Local\Temp\ipykernel_15140\1485728669.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
#    first  last  email
# 0      5     7     22
# 1      4     3     17
# 2      4     3     17

# %%
df.map(len)
# Out:
#    first  last  email
# 0      5     7     22
# 1      4     3     17
# 2      4     3     17

# %%
df = df.map(str.upper)

# %%
df = df.map(str.lower)

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   jane      doe       janedoe@email.com
# 2   john      doe       johndoe@email.com

# %%
df['first'] = df['first'].map({'corey': 'Chris', 'jane': 'Jack'})

# %%
df['first']
# Out:
# 0    Chris
# 1     Jack
# 2      NaN
# Name: first, dtype: object

# %%
df['first'] = df['first'].fillna('john')

# %%
df['first']
# Out:
# 0    Chris
# 1     Jack
# 2     john
# Name: first, dtype: object

# %%
df['first'] = df['first'].replace({'Chris': 'Corey', 'Jack':'Jane'})

# %%
df['first']
# Out:
# 0    Corey
# 1     Jane
# 2     john
# Name: first, dtype: object

# %%
df
# Out:
#    first     last                   email
# 0  Corey  schafer  coreyschafer@email.com
# 1   Jane      doe       janedoe@email.com
# 2   john      doe       johndoe@email.com

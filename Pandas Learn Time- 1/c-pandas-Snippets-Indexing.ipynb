# %%
import pandas as pd

# %%
person = {
 "first" : "corey",
 "last" : "schafer",
"email" :"coreyschafer@email.com"
}


people = {
 "first" : ["corey"],
 "last" : ["schafer"],
"email" : ["coreyschafer@email.com"]
}

people = {
 "first" : ['corey', 'Jane', 'John'],
 "last" : ['schafer', 'Doe', 'Doe'],
"email" : ['coreyschafer@email.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
people['email']
# Out:
# ['coreyschafer@email.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
dff = pd.DataFrame(people)

# %%
dff['email']
# Out:
# 0    coreyschafer@email.com
# 1         JaneDoe@email.com
# 2         JohnDoe@email.com
# Name: email, dtype: object

# %%
dff.email
# Out:
# 0    coreyschafer@email.com
# 1         JaneDoe@email.com
# 2         JohnDoe@email.com
# Name: email, dtype: object

# %%
dff
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
dff[['last','email']]
# Out:
#       last                   email
# 0  schafer  coreyschafer@email.com
# 1      Doe       JaneDoe@email.com
# 2      Doe       JohnDoe@email.com

# %%
dff.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
dff.iloc[0]
# Out:
# first                     corey
# last                    schafer
# email    coreyschafer@email.com
# Name: 0, dtype: object

# %%
dff.iloc[0,1]
# Out:
# 'schafer'

# %%
dff.shape
# Out:
# (3, 3)

# %%
dff.iloc[[0,1,2],[0,1,2]]
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
dff.iloc[0:3,0:3]
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
dff.loc[[0,1,2],['email', 'last']]
# Out:
#                     email     last
# 0  coreyschafer@email.com  schafer
# 1       JaneDoe@email.com      Doe
# 2       JohnDoe@email.com      Doe

# %%
dff.loc[0]
# Out:
# first                     corey
# last                    schafer
# email    coreyschafer@email.com
# Name: 0, dtype: object

# %%
dff.loc[0:2]
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
dff.loc[0:2,'first':'last']
# Out:
#    first     last
# 0  corey  schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
dff.iloc[0]
# Out:
# first                     corey
# last                    schafer
# email    coreyschafer@email.com
# Name: 0, dtype: object

# %%
dff.iloc[0:3, 0:3]
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
dff.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
# INDEXES [How to set Index, Reset, Use of Indexes]

# %%
dff
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
dff['email']
# Out:
# 0    coreyschafer@email.com
# 1         JaneDoe@email.com
# 2         JohnDoe@email.com
# Name: email, dtype: object

# %%
#Now I want to set the email as the index, so we can have some meaningful name to the index value
dff.set_index('email',inplace=True)

# %%
dff
# Out:
#                         first     last
# email
# coreyschafer@email.com  corey  schafer
# JaneDoe@email.com        Jane      Doe
# JohnDoe@email.com        John      Doe

# %%
dff.index
# Out:
# Index(['coreyschafer@email.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='object', name='email')

# %%
dff.loc['coreyschafer@email.com']
# Out:
# first      corey
# last     schafer
# Name: coreyschafer@email.com, dtype: object

# %%
dff.loc['coreyschafer@email.com':'JohnDoe@email.com']
# Out:
#                         first     last
# email
# coreyschafer@email.com  corey  schafer
# JaneDoe@email.com        Jane      Doe
# JohnDoe@email.com        John      Doe

# %%
dff['last']
# Out:
# email
# coreyschafer@email.com    schafer
# JaneDoe@email.com             Doe
# JohnDoe@email.com             Doe
# Name: last, dtype: object

# %%
(dff['last'] == 'Doe') & (dff['first'] == 'Jane')
# Out:
# email
# coreyschafer@email.com    False
# JaneDoe@email.com          True
# JohnDoe@email.com         False
# dtype: bool

# %%
dff[(dff['last'] == 'Doe') & (dff['first'] == 'Jane')]
# Out:
#                   first last
# email
# JaneDoe@email.com  Jane  Doe

# %%
filt = (dff['last'] == 'Doe') & (dff['first'] == 'Jane')
dff.loc[filt, 'last']
# Out:
# email
# JaneDoe@email.com    Doe
# Name: last, dtype: object

# %%
dff = dff.reset_index()

# %%
filt = (dff['last'] == 'Doe') & (dff['first'] == 'Jane')
dff.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: object

# %%
filt = (dff['last'] == 'schafer') | (dff['first'] == 'John')
dff.loc[filt, 'email']
# Out:
# 0    coreyschafer@email.com
# 2         JohnDoe@email.com
# Name: email, dtype: object

# %%
dff.loc[~filt, 'email']
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: object

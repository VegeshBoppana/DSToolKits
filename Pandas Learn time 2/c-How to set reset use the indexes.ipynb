# %%
import pandas as pd
import numpy as np

# %%
people = {
 "first" : ['corey', 'Jane', 'John'],
 "last" : ['schafer', 'Doe', 'Doe'],
"email" : ['coreyschafer@email.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
df = pd.DataFrame(people)

# %%
df.head()
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
#set the email as the index

df.set_index('email',inplace = True)

# %%
df
# Out:
#                         first     last
# email
# coreyschafer@email.com  corey  schafer
# JaneDoe@email.com        Jane      Doe
# JohnDoe@email.com        John      Doe

# %%
df.loc['coreyschafer@email.com','first']
# Out:
# 'corey'

# %%
df.loc['coreyschafer@email.com']
# Out:
# first      corey
# last     schafer
# Name: coreyschafer@email.com, dtype: object

# %%
df.iloc[0]
# Out:
# first      corey
# last     schafer
# Name: coreyschafer@email.com, dtype: object

# %%
#reset the index
df.reset_index(inplace = True)

# %%
df.loc[0]
# Out:
# email    coreyschafer@email.com
# first                     corey
# last                    schafer
# Name: 0, dtype: object

# %%
import numpy as np
import pandas as pd

# %%
people = {
 "first" : ['corey', 'Jane', 'John'],
 "last" : ['schafer', 'Doe', 'Doe'],
"email" : ['coreyschafer@email.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
df = pd.DataFrame(people)

# %%
df.columns=['first_name','last_name',"fullemail"]

# %%
df
# Out:
#   first_name last_name               fullemail
# 0      corey   schafer  coreyschafer@email.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME LAST_NAME               FULLEMAIL
# 0      corey   schafer  coreyschafer@email.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.columns = df.columns.str.replace('_',' ')

# %%
df
# Out:
#   FIRST NAME LAST NAME               FULLEMAIL
# 0      corey   schafer  coreyschafer@email.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df
# Out:
#   FIRST_NAME LAST_NAME               FULLEMAIL
# 0      corey   schafer  coreyschafer@email.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df
# Out:
#   first_name last_name               fullemail
# 0      corey   schafer  coreyschafer@email.com
# 1       Jane       Doe       JaneDoe@email.com
# 2       John       Doe       JohnDoe@email.com

# %%
df.rename(columns={'first_name': 'first'},inplace=True)

# %%
df
# Out:
#    first last_name               fullemail
# 0  corey   schafer  coreyschafer@email.com
# 1   Jane       Doe       JaneDoe@email.com
# 2   John       Doe       JohnDoe@email.com

# %%
df.loc[2]
# Out:
# first                     John
# last_name                  Doe
# fullemail    JohnDoe@email.com
# Name: 2, dtype: object

# %%
df.loc[2] = ['John', 'Smith', 'JohnSmith@email.com']

# %%
df.loc[2,['last','email']] = ['Doe','JohnDoe@email.com']

# %%
df
# Out:
#    first last_name               fullemail last              email
# 0  corey   schafer  coreyschafer@email.com  NaN                NaN
# 1   Jane       Doe       JaneDoe@email.com  NaN                NaN
# 2   John     Smith     JohnSmith@email.com  Doe  JohnDoe@email.com

# %%
df.at[2,'last'] = 'Doeee'

# %%
df
# Out:
#    first last_name               fullemail   last              email
# 0  corey   schafer  coreyschafer@email.com    NaN                NaN
# 1   Jane       Doe       JaneDoe@email.com    NaN                NaN
# 2   John     Smith     JohnSmith@email.com  Doeee  JohnDoe@email.com

# %%
df['last'].fillna('yoyo',inplace=True)

# %%
df
# Out:
#    first last_name               fullemail   last              email
# 0  corey   schafer  coreyschafer@email.com   yoyo                NaN
# 1   Jane       Doe       JaneDoe@email.com   yoyo                NaN
# 2   John     Smith     JohnSmith@email.com  Doeee  JohnDoe@email.com

# %%
filt = (df.fullemail == 'JaneDoe@email.com')

# %%
df.loc[filt,'last'] = ['Doe']

### df[filt,'last'] = ['Doe']  this code which is commented will not work

# %%
df
# Out:
#    first last_name               fullemail   last              email
# 0  corey   schafer  coreyschafer@email.com   yoyo                NaN
# 1   Jane       Doe       JaneDoe@email.com    Doe                NaN
# 2   John     Smith     JohnSmith@email.com  Doeee  JohnDoe@email.com

# %%
df.loc[1, 'fullemail'] = df.loc[1, 'fullemail'].lower()

# %%
df
# Out:
#    first last_name               fullemail   last              email
# 0  corey   schafer  coreyschafer@email.com   yoyo                NaN
# 1   Jane       Doe       janedoe@email.com    Doe                NaN
# 2   John     Smith     JohnSmith@email.com  Doeee  JohnDoe@email.com

# %%
# apply, applymap, map, replace, rename

# apply works differently on the series and the dataframe, be careful with that

# applymap is depreceated use map instead

# %%
df.apply(len, axis = 'columns')
# Out:
# 0    5
# 1    5
# 2    5
# dtype: int64

# %%
df.apply(len)
# Out:
# first        3
# last_name    3
# fullemail    3
# last         3
# email        3
# dtype: int64

# %%
df.loc[:, 'first':'last'].apply(pd.Series.min)
# Out:
# first                       Jane
# last_name                    Doe
# fullemail    JohnSmith@email.com
# last                         Doe
# dtype: object

# %%
df['email'].fillna('y', inplace=True)

# %%
df.applymap(len)
# Out:
# C:\Users\vegeshsai_boppana\AppData\Local\Temp\ipykernel_24216\1485728669.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
#    first  last_name  fullemail  last  email
# 0      5          7         22     4      1
# 1      4          3         17     3      1
# 2      4          5         19     5     17

# %%
df.map(len)
# Out:
#    first  last_name  fullemail  last  email
# 0      5          7         22     4      1
# 1      4          3         17     3      1
# 2      4          5         19     5     17

# %%
df['first'] = df['first'].map({'corey': 'Chris', 'jane': 'Jack'})

# %%
df
# Out:
#    first last_name               fullemail   last              email
# 0  Chris   schafer  coreyschafer@email.com   yoyo                  y
# 1    NaN       Doe       janedoe@email.com    Doe                  y
# 2    NaN     Smith     JohnSmith@email.com  Doeee  JohnDoe@email.com

# %%
df['first'].fillna(df['last_name'],inplace=True)
# Out:
# C:\Users\vegeshsai_boppana\AppData\Local\Temp\ipykernel_24216\603404009.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['first'].fillna(df['last_name'],inplace=True)

# %%
df
# Out:
#      first last_name               fullemail   last              email
# 0  schafer   schafer  coreyschafer@email.com   yoyo                  y
# 1      Doe       Doe       janedoe@email.com    Doe                  y
# 2    Smith     Smith     JohnSmith@email.com  Doeee  JohnDoe@email.com

# %%
df['first'].replace({'Doe':'Dog'}, inplace= True)

# %%
df
# Out:
#      first last_name               fullemail   last              email
# 0  schafer   schafer  coreyschafer@email.com   yoyo                  y
# 1      Dog       Doe       janedoe@email.com    Doe                  y
# 2    Smith     Smith     JohnSmith@email.com  Doeee  JohnDoe@email.com

# %%
df['boolean'] = 'Yes'

# %%
df
# Out:
#      first last_name               fullemail   last              email boolean
# 0  schafer   schafer  coreyschafer@email.com   yoyo                  y     Yes
# 1      Dog       Doe       janedoe@email.com    Doe                  y     Yes
# 2    Smith     Smith     JohnSmith@email.com  Doeee  JohnDoe@email.com     Yes

# %%
df['boolean'].replace({'Yes':'True'}, inplace = True)

# %%
df
# Out:
#      first last_name               fullemail   last              email boolean
# 0  schafer   schafer  coreyschafer@email.com   yoyo                  y    True
# 1      Dog       Doe       janedoe@email.com    Doe                  y    True
# 2    Smith     Smith     JohnSmith@email.com  Doeee  JohnDoe@email.com    True

# %%
df['boolean'].map({'True' : 'Yes'})
# Out:
# 0    Yes
# 1    Yes
# 2    Yes
# Name: boolean, dtype: object

# %%
df
# Out:
#      first last_name               fullemail   last              email boolean
# 0  schafer   schafer  coreyschafer@email.com   yoyo                  y    True
# 1      Dog       Doe       janedoe@email.com    Doe                  y    True
# 2    Smith     Smith     JohnSmith@email.com  Doeee  JohnDoe@email.com    True

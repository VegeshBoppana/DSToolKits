# %%
import pandas as pd

# %%
person = {
 "first" : "corey",
 "last" : "schafer",
"email" :"coreyschafer@email.com"
}


people = {
 "first" : ["corey"],
 "last" : ["schafer"],
"email" : ["coreyschafer@email.com"]
}

people = {
 "first" : ['corey', 'Jane', 'John'],
 "last" : ['schafer', 'Doe', 'Doe'],
"email" : ['coreyschafer@email.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
df.email
# Out:
# 0    coreyschafer@email.com
# 1         JaneDoe@email.com
# 2         JohnDoe@email.com
# Name: email, dtype: object

# %%
df['fullname'] = df['first']+df['last']

# %%
df
# Out:
#    first     last                   email      fullname
# 0  corey  schafer  coreyschafer@email.com  coreyschafer
# 1   Jane      Doe       JaneDoe@email.com       JaneDoe
# 2   John      Doe       JohnDoe@email.com       JohnDoe

# %%
df[['email','last']]
# Out:
#                     email     last
# 0  coreyschafer@email.com  schafer
# 1       JaneDoe@email.com      Doe
# 2       JohnDoe@email.com      Doe

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
type(df[['email','last']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['first', 'last', 'email', 'fullname'], dtype='object')

# %%
df.iloc[0]
# Out:
# first                        corey
# last                       schafer
# email       coreyschafer@email.com
# fullname              coreyschafer
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# first                        corey
# last                       schafer
# email       coreyschafer@email.com
# fullname              coreyschafer
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#    first     last                   email      fullname
# 0  corey  schafer  coreyschafer@email.com  coreyschafer
# 1   Jane      Doe       JaneDoe@email.com       JaneDoe

# %%
df.iloc[[0,1],3]
# Out:
# 0    coreyschafer
# 1         JaneDoe
# Name: fullname, dtype: object

# %%
df.loc[[0,1],'email']
# Out:
# 0    coreyschafer@email.com
# 1         JaneDoe@email.com
# Name: email, dtype: object

# %%
df.loc[[0,1],['email','last']]
# Out:
#                     email     last
# 0  coreyschafer@email.com  schafer
# 1       JaneDoe@email.com      Doe

# %%
df.loc[[0,2],['email','last']]
# Out:
#                     email     last
# 0  coreyschafer@email.com  schafer
# 2       JohnDoe@email.com      Doe

# %%
df.loc[[0,2],['last','email',]]
# Out:
#       last                   email
# 0  schafer  coreyschafer@email.com
# 2      Doe       JohnDoe@email.com

# %%
df.value_counts()
# Out:
# first  last     email                   fullname
# Jane   Doe      JaneDoe@email.com       JaneDoe         1
# John   Doe      JohnDoe@email.com       JohnDoe         1
# corey  schafer  coreyschafer@email.com  coreyschafer    1
# Name: count, dtype: int64

# %%
df.email.value_counts()
# Out:
# email
# coreyschafer@email.com    1
# JaneDoe@email.com         1
# JohnDoe@email.com         1
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

# %%
people = {
 "first" : ['corey', 'Jane', 'John'],
 "last" : ['schafer', 'Doe', 'Doe'],
"email" : ['coreyschafer@email.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com
# 1   Jane      Doe       JaneDoe@email.com
# 2   John      Doe       JohnDoe@email.com

# %%
filt = (df['last'] == 'schafer')
df[filt].email
# Out:
# 0    coreyschafer@email.com
# Name: email, dtype: object

# %%
df.loc[filt]
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@email.com

# %%
df.loc[filt,'email']
# Out:
# 0    coreyschafer@email.com
# Name: email, dtype: object

# %%
filt = (df['last'] == 'schafer') | (df['first'] == 'John')

# %%
df.loc[~filt, 'email']
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: object

# %%
df.loc[~filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com

# %%
df = pd.read_csv('C:\DSToolKits\data\survey_results_public.csv')

# %%
dff = pd.read_csv('C:\DSToolKits\data\survey_results_schema.csv')

# %%
dff.set_index('Column', inplace = True)

# %%
dff.loc['Country','QuestionText']
# Out:
# 'In which country do you currently reside?'

# %%
df.Country.value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Papua New Guinea                        1
# Saint Kitts and Nevis                   1
# Saint Vincent and the Grenadines        1
# Sao Tome and Principe                   1
# Chad                                    1
# Name: count, Length: 179, dtype: int64

# %%
countries = ['United States', 'India', 'Germany', 'Canada']

# %%
filt = df['Country'].isin(countries)

# %%
df.loc[filt,'Country']
# Out:
# 3        United States
# 5               Canada
# 7                India
# 9                India
# 11              Canada
#              ...
# 88855           Canada
# 88859    United States
# 88864            India
# 88877    United States
# 88878           Canada
# Name: Country, Length: 39271, dtype: object

# %%
programmingfilt = df['LanguageWorkedWith'].str.contains('Python',na = False)

# %%
df.loc[programmingfilt,'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

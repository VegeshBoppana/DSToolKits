# %%
import numpy as np

# %%
a = np.array([[1,2,3],[4,5,6]])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
b = 5
print(a+b)
# Out:
# [[ 6  7  8]
#  [ 9 10 11]]

# %%
c = np.array([2])
print(c.shape)
print(a+c)
# Out:
# (1,)
# [[3 4 5]
#  [6 7 8]]
